# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
import numpy as np

# Step 1: Load the dataset
file_path = 'school_data.csv'
df = pd.read_csv(file_path)

# Step 2.1: Explode Positions
# Split the 'Position' column into multiple rows for players with multiple positions
df['Position'] = df['Position'].str.split(', ')
df_exploded = df.explode('Position').reset_index(drop=True)

# Step 2.2: Normalize the numerical columns
numeric_cols = df_exploded.select_dtypes(include=['float64', 'int64']).columns
scaler = StandardScaler()
df_exploded[numeric_cols] = scaler.fit_transform(df_exploded[numeric_cols])

# Step 2.3: One-hot encode the 'Position' column
df_encoded = pd.get_dummies(df_exploded, columns=['Position'])

# Step 2.4: Handle missing values by dropping rows with NaNs
df_cleaned = df_encoded.dropna().reset_index(drop=True)
df_exploded = df_exploded.loc[df_cleaned.index].reset_index(drop=True)

# Step 3: Unsupervised Learning using Autoencoder
# Set features for the autoencoder
X = df_cleaned.drop(columns=['player_name', 'team']).values.astype(np.float32)

# Step 3.1: Define the autoencoder model
input_dim = X.shape[1]
encoding_dim = 32  # Size of the encoded representation

input_layer = Input(shape=(input_dim,))
encoded = Dense(encoding_dim, activation='relu')(input_layer)
decoded = Dense(input_dim, activation='linear')(encoded)

autoencoder = Model(inputs=input_layer, outputs=decoded)
encoder = Model(inputs=input_layer, outputs=encoded)

# Step 3.2: Compile and train the autoencoder
autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.fit(X, X, epochs=50, batch_size=32, shuffle=True, validation_split=0.2, verbose=0)

# Step 4: Use the encoded representation to rank players
encoded_features = encoder.predict(X)

# Step 4.1: Calculate ranking score based on the encoded features
df_cleaned['ranking'] = encoded_features[:, 0]  # Using the first encoded feature for ranking

# Step 5: Create separate dataframes for each position with rankings
# Re-merge position information with player names and teams
df_cleaned['player_name'] = df_exploded['player_name']
df_cleaned['team'] = df_exploded['team']
df_cleaned['Position'] = df_exploded['Position']

# Step 5.1: Group by position and create separate dataframes for each position
position_groups = df_cleaned.groupby('Position')
position_dataframes = {}

for position, group in position_groups:
    position_df_name = f"{position.lower()}_position_df"
    position_df = group[['player_name', 'team', 'ranking']].sort_values(by='ranking', ascending=False)
    position_dataframes[position] = position_df
    globals()[position_df_name] = position_df  # Create a dataframe variable with the name xx_position_df
    print(f"Displaying Player Rankings for Position: {position}")
print(position_df.head())
# Out:
# 10/10 [==============================] - 0s 922us/step
# Displaying Player Rankings for Position: 0
# Displaying Player Rankings for Position: AMF
# Displaying Player Rankings for Position: CB
# Displaying Player Rankings for Position: CF
# Displaying Player Rankings for Position: DMF
# Displaying Player Rankings for Position: GK
# Displaying Player Rankings for Position: LAMF
# Displaying Player Rankings for Position: LB
# Displaying Player Rankings for Position: LB5
# Displaying Player Rankings for Position: LCB
# Displaying Player Rankings for Position: LCB3
# Displaying Player Rankings for Position: LCMF
# Displaying Player Rankings for Position: LCMF3
# Displaying Player Rankings for Position: LDMF
# Displaying Player Rankings for Position: LW
# Displaying Player Rankings for Position: LWF
# Displaying Player Rankings for Position: RAMF
# Displaying Player Rankings for Position: RB
# Displaying Player Rankings for Position: RB5
# Displaying Player Rankings for Position: RCB
# Displaying Player Rankings for Position: RCB3
# Displaying Player Rankings for Position: RCMF
# Displaying Player Rankings for Position: RCMF3
# Displaying Player Rankings for Position: RDMF
# Displaying Player Rankings for Position: RW
# Displaying Player Rankings for Position: RWB
# Displaying Player Rankings for Position: RWF
#      player_name                     team   ranking
# 288  T. Angelone  Rutgers Scarlet Knights  1.159277
# 65   C. Lawrence      Michigan Wolverines  0.212729
# 279    S. Rincón              UCLA Bruins  0.000000

# %%
position_dataframes
# Out:
# {'0':          player_name                             team   ranking
#  57     C. Fitzgerald  Maryland College Park Terrapins  2.223408
#  132        J. Demian                 Indiana Hoosiers  2.191338
#  142       J. Maguire               Washington Huskies  1.806891
#  143    J. Maguire(1)               Washington Huskies  1.806891
#  86           D. Hass             Detroit Mercy Titans  1.751134
#  55      C. Desroches              Ohio State Buckeyes  1.350482
#  199         M. Nesci                 Indiana Hoosiers  0.570634
#  31        B. Keating          Rutgers Scarlet Knights  0.567461
#  41   B. Saint Martin  Maryland College Park Terrapins  0.292319
#  39         B. Minzey                 Indiana Hoosiers  0.234468
#  145         J. Mason          Michigan State Spartans  0.000000
#  171       L. Bezerra                 Indiana Hoosiers  0.000000
#  216      N. Cassiday              Michigan Wolverines  0.000000
#  259         R. Keefe                Wisconsin Badgers  0.000000,
#  'AMF':       player_name                             team   ranking
#  313     Z. Babiak          Michigan State Spartans  3.749792
#  194  M. Hrvojevic                Wisconsin Badgers  1.778881
#  305  V. Danielson          Penn State Nittany Lion  1.630332
#  52   C. Crockford                Wisconsin Badgers  1.220649
#  121     I. Tyrkus          Rutgers Scarlet Knights  0.989978
#  186   M. De Jesus  Maryland College Park Terrapins  0.884021
#  35      B. Madore          Penn State Nittany Lion  0.862031
#  229  N. Rosamilia          Rutgers Scarlet Knights  0.780212
#  149      J. Ramos              Michigan Wolverines  0.272747
#  213    N. Cabrera          Rutgers Scarlet Knights  0.058185
#  5       A. Camara          Penn State Nittany Lion  0.000000
#  14    A. Ndrenika  Maryland College Park Terrapins  0.000000
#  49       C. Calov          Rutgers Scarlet Knights  0.000000
#  165  K. Arnarsson          Rutgers Scarlet Knights  0.000000,
#  'CB':           player_name                     team   ranking
#  312         Y. Senden              UCLA Bruins  0.665266
#  0    A. Adalsteinsson  Rutgers Scarlet Knights  0.000000
#  227         N. Prince    Northwestern Wildcats  0.000000
#  238         P. Grassi              UCLA Bruins  0.000000
#  243          P. Lurot      Michigan Wolverines  0.000000,
#  'CF':          player_name                             team   ranking
#  58         C. Gerber  Maryland College Park Terrapins  2.129382
#  285       S. Stewart                 Indiana Hoosiers  1.923490
#  118     I. Addimandi            Northwestern Wildcats  1.646913
#  23           A. Vovk                      UCLA Bruins  1.550483
#  99         E. Emovon          Michigan State Spartans  1.524412
#  231         N. Røjel                      UCLA Bruins  1.461543
#  236        O. Martin              Michigan Wolverines  1.286289
#  122        I. Tyrkus          Rutgers Scarlet Knights  1.248839
#  232        N. Skubis              Ohio State Buckeyes  1.218528
#  36         B. Madore          Penn State Nittany Lion  1.120892
#  89          D. Obilo              Michigan Wolverines  1.029519
#  10           A. Hall               Washington Huskies  1.022627
#  304         U. Zeitz              Michigan Wolverines  1.012446
#  73         C. Oliver          Penn State Nittany Lion  0.978767
#  170        L. Aviles          Rutgers Scarlet Knights  0.928402
#  209          M. Saad          Michigan State Spartans  0.811007
#  235       O. Maeland          Rutgers Scarlet Knights  0.672252
#  133          J. Diaz                      UCLA Bruins  0.655108
#  150         J. Ramos              Michigan Wolverines  0.531608
#  247          P. Naef                      UCLA Bruins  0.348686
#  196          M. Leon              Michigan Wolverines  0.317648
#  154         J. Stout          Michigan State Spartans  0.264469
#  197         M. Lynch          Rutgers Scarlet Knights  0.245080
#  11           A. Kato          Penn State Nittany Lion  0.232195
#  272      S. Kerrigan          Michigan State Spartans  0.209789
#  290        T. Dewing            Northwestern Wildcats  0.192168
#  60       C. Griffith  Maryland College Park Terrapins  0.139993
#  96          D. Wrona              Ohio State Buckeyes  0.051712
#  296       T. Mihalić                 Indiana Hoosiers  0.000000
#  226       N. O'Brien               Washington Huskies  0.000000
#  297     T. Raimbault                Wisconsin Badgers  0.000000
#  289        T. Creech              Ohio State Buckeyes  0.000000
#  242      P. Kingston               Washington Huskies  0.000000
#  291       T. Fleming                Wisconsin Badgers  0.000000
#  254          R. Aman               Washington Huskies  0.000000
#  256          R. Eisa                Wisconsin Badgers  0.000000
#  275      S. Masereka  Maryland College Park Terrapins  0.000000
#  222        N. Joseph                 Indiana Hoosiers  0.000000
#  6          A. Camara          Penn State Nittany Lion  0.000000
#  174        L. Jeffus                 Indiana Hoosiers  0.000000
#  206        M. Rogers  Maryland College Park Terrapins  0.000000
#  129       J. Contell                      UCLA Bruins  0.000000
#  18          A. Ochoa                      UCLA Bruins  0.000000
#  25           A.Awujo            Northwestern Wildcats  0.000000
#  30       B. Clagette            Northwestern Wildcats  0.000000
#  63       C. Kosakoff               Washington Huskies  0.000000
#  81         D. Ajagbe              Ohio State Buckeyes  0.000000
#  110      G. Elmquist              Michigan Wolverines  0.000000
#  126       J. Bucknor              Michigan Wolverines  0.000000
#  137      J. Guggemos          Michigan State Spartans  0.000000
#  204       M. Ramirez            Northwestern Wildcats  0.000000
#  152     J. Spadafora          Michigan State Spartans  0.000000
#  153  J. Spadafora(1)          Michigan State Spartans  0.000000
#  160         J. Weiss                 Indiana Hoosiers  0.000000
#  181  L. Van Heukelum  Maryland College Park Terrapins  0.000000
#  183      M. Borkovic              Ohio State Buckeyes  0.000000
#  188          M. Diop               Washington Huskies  0.000000
#  192         M. Hewes          Penn State Nittany Lion  0.000000
#  311         W. Smith                Wisconsin Badgers  0.000000,
#  'DMF':        player_name               team   ranking
#  79    C. Wilkerson        UCLA Bruins  0.968765
#  221    N. Glorioso  Wisconsin Badgers  0.467783
#  163     K. Andrews  Wisconsin Badgers  0.341283
#  295  T. Karumanchi        UCLA Bruins  0.000000,
#  'GK':           player_name                             team   ranking
#  7            A. Cooke          Penn State Nittany Lion  5.058300
#  54          C. Dalton          Rutgers Scarlet Knights  4.527382
#  108        F. Grundin          Penn State Nittany Lion  4.279208
#  114          H. Brown               Virginia Cavaliers  4.234801
#  113       H. Blatteis  Maryland College Park Terrapins  4.171796
#  138          J. Harms                 Indiana Hoosiers  3.992606
#  104           E. Wood             Detroit Mercy Titans  3.952253
#  119        I. Goldson              Michigan Wolverines  3.891824
#  115          H. Evans              Michigan Wolverines  3.817603
#  125         J. Bowton               Washington Huskies  3.771760
#  4           A. Braman                Wisconsin Badgers  2.947790
#  287        S. Wolcott  Maryland College Park Terrapins  1.550206
#  310         W. Nelson                      UCLA Bruins  1.262748
#  314          Z. Kelly          Michigan State Spartans  0.571874
#  246     P. McLaughlin              Ohio State Buckeyes  0.341938
#  176           L. Mack  Maryland College Park Terrapins  0.000000
#  191        M. Herbert                Wisconsin Badgers  0.000000
#  211          M. Trejo              Ohio State Buckeyes  0.000000
#  265  R. Ponce de leon            Northwestern Wildcats  0.000000
#  271         S. Joseph                      UCLA Bruins  0.000000,
#  'LAMF':        player_name                             team   ranking
#  106   F. Di Ponzio          Rutgers Scarlet Knights  1.112035
#  61     C. Griffith  Maryland College Park Terrapins  0.128462
#  27      B. Blevins              Michigan Wolverines  0.000000
#  50        C. Calov          Rutgers Scarlet Knights  0.000000
#  59   C. Grabfelder          Penn State Nittany Lion  0.000000
#  167      K. Dadzie          Penn State Nittany Lion  0.000000
#  207      M. Rogers  Maryland College Park Terrapins  0.000000
#  230   N. Rosamilia          Rutgers Scarlet Knights  0.000000
#  263       R. Perez              Michigan Wolverines  0.000000
#  306       V. Kovac          Michigan State Spartans  0.000000,
#  'LB':         player_name                             team   ranking
#  190    M. Henderson          Penn State Nittany Lion  3.337608
#  178     L. Shreiner            Northwestern Wildcats  1.383435
#  111    G. Fernandez               Washington Huskies  0.964022
#  268       S. Godden          Rutgers Scarlet Knights  0.398026
#  293    T. Glassberg            Northwestern Wildcats  0.039235
#  2         A. Barger                 Indiana Hoosiers  0.000000
#  26   B. Baldvinsson                Wisconsin Badgers  0.000000
#  40        B. Munson          Michigan State Spartans  0.000000
#  70        C. Meyers               Washington Huskies  0.000000
#  94       D. Vellios              Ohio State Buckeyes  0.000000
#  109       F. Volmar            Northwestern Wildcats  0.000000
#  172    L. Costabile  Maryland College Park Terrapins  0.000000
#  189       M. Fisher              Michigan Wolverines  0.000000
#  273         S. Koza          Rutgers Scarlet Knights  0.000000
#  308          W. Eby          Michigan State Spartans  0.000000,
#  'LB5':       player_name                     team   ranking
#  269     S. Godden  Rutgers Scarlet Knights  0.057918
#  217    N. Cavallo              UCLA Bruins  0.000000
#  294  T. Glassberg    Northwestern Wildcats  0.000000,
#  'LCB':           player_name                             team   ranking
#  278         S. Ovesen          Penn State Nittany Lion  1.763241
#  116        H. Richter            Northwestern Wildcats  1.383170
#  130         J. Cortez                      UCLA Bruins  1.328853
#  187        M. Devries  Maryland College Park Terrapins  1.105398
#  95        D. Williams              Ohio State Buckeyes  0.765235
#  74          C. Oliver          Penn State Nittany Lion  0.748213
#  267   S. Bettenhausen          Penn State Nittany Lion  0.238022
#  1    A. Adalsteinsson          Rutgers Scarlet Knights  0.000000
#  184         M. Cisset          Penn State Nittany Lion  0.000000
#  261          R. Mayer            Northwestern Wildcats  0.000000
#  220         N. Demian              Ohio State Buckeyes  0.000000
#  144          J. Maher                 Indiana Hoosiers  0.000000
#  173       L. Gerhardt          Michigan State Spartans  0.000000
#  161       J. Zalinsky          Rutgers Scarlet Knights  0.000000
#  43         B. Thiesen  Maryland College Park Terrapins  0.000000
#  141      J. Lindimore                 Indiana Hoosiers  0.000000
#  112         H. Bertos               Washington Huskies  0.000000
#  83           D. Brown                Wisconsin Badgers  0.000000
#  307          W. Baker              Michigan Wolverines  0.000000,
#  'LCB3':     player_name                     team   ranking
#  8      A. Flynn  Rutgers Scarlet Knights  1.509578
#  281    S. Scott              UCLA Bruins  1.330482
#  239   P. Grassi              UCLA Bruins  0.000000
#  262    R. Mayer    Northwestern Wildcats  0.000000,
#  'LCMF':           player_name                             team   ranking
#  286      S. Vainstein          Penn State Nittany Lion  3.944452
#  302         T. Wright                      UCLA Bruins  1.787034
#  164        K. Andrews                Wisconsin Badgers  1.588799
#  177        L. Pechota              Ohio State Buckeyes  1.407246
#  282           S. Sent               Washington Huskies  1.302592
#  93            D. Tran            Northwestern Wildcats  1.277218
#  203        M. Ramirez            Northwestern Wildcats  1.274936
#  13          A. Narang                      UCLA Bruins  1.163937
#  168  K. Quist-Therson  Maryland College Park Terrapins  1.113109
#  102           E. Ruiz          Rutgers Scarlet Knights  0.553222
#  200         M. Parker              Michigan Wolverines  0.516204
#  155       J. Suchecki            Northwestern Wildcats  0.236579
#  101      E. Popkewitz                Wisconsin Badgers  0.187626
#  252         Q. Rogers              Michigan Wolverines  0.000000
#  298      T. Raimbault                Wisconsin Badgers  0.000000
#  32           B. LeBel            Northwestern Wildcats  0.000000
#  46        C. Bruletti          Michigan State Spartans  0.000000
#  277          S. Nixon                      UCLA Bruins  0.000000
#  257        R. Gourdie               Washington Huskies  0.000000
#  139           J. Kuhr                Wisconsin Badgers  0.000000
#  244       P. McDonald                 Indiana Hoosiers  0.000000
#  20         A. Roberts              Ohio State Buckeyes  0.000000
#  166          K. Brame              Michigan Wolverines  0.000000
#  134       J. Gajadhar            Northwestern Wildcats  0.000000
#  158        J. Wagoner                 Indiana Hoosiers  0.000000
#  223        N. McHenry              Ohio State Buckeyes  0.000000,
#  'LCMF3':        player_name                     team   ranking
#  270    S. Hauksson              UCLA Bruins  3.688768
#  169  K. Schueneman  Michigan State Spartans  2.210390
#  80    C. Wilkerson              UCLA Bruins  0.860569
#  249       P. Reisz    Northwestern Wildcats  0.677898
#  19        A. Ochoa              UCLA Bruins  0.000000,
#  'LDMF':          player_name                             team   ranking
#  175         L. Koehl  Maryland College Park Terrapins  3.654872
#  315       Z. Martens              Michigan Wolverines  0.598414
#  201        M. Parker              Michigan Wolverines  0.308934
#  214       N. Cabrera          Rutgers Scarlet Knights  0.084724
#  53       C. Cruthers          Rutgers Scarlet Knights  0.015804
#  76   C. Steinleitner  Maryland College Park Terrapins  0.000000
#  105          F. Bell          Penn State Nittany Lion  0.000000,
#  'LW':          player_name                             team   ranking
#  146        J. Michel  Maryland College Park Terrapins  1.721488
#  284          S. Soga          Michigan State Spartans  1.293969
#  71        C. Murador                 Indiana Hoosiers  1.287312
#  62          C. Heuer                 Indiana Hoosiers  0.928281
#  9            A. Hall               Washington Huskies  0.779612
#  318        Z. Ramsey               Washington Huskies  0.356729
#  195     M. Lejbowicz  Maryland College Park Terrapins  0.299509
#  299     T. Raimbault                Wisconsin Badgers  0.271099
#  68         C. McCamy            Northwestern Wildcats  0.000000
#  51          C. Calov          Rutgers Scarlet Knights  0.000000
#  72          C. Oduro                 Indiana Hoosiers  0.000000
#  82          D. Boltz                Wisconsin Badgers  0.000000
#  135      J. Gajadhar            Northwestern Wildcats  0.000000
#  28        B. Blevins              Michigan Wolverines  0.000000
#  151         J. Sharp          Michigan State Spartans  0.000000
#  157  J. Van Deventer            Northwestern Wildcats  0.000000
#  182      M. Adedokun              Ohio State Buckeyes  0.000000
#  233        N. Skubis              Ohio State Buckeyes  0.000000
#  258       R. Gourdie               Washington Huskies  0.000000
#  42           B. Soto              Michigan Wolverines  0.000000
#  303        T. Wright                      UCLA Bruins  0.000000,
#  'LWF':     player_name                 team  ranking
#  64  C. Lawrence  Michigan Wolverines      0.0,
#  'RAMF':      player_name                             team   ranking
#  22   A. Sheppela  Maryland College Park Terrapins  2.023288
#  75    C. Peretti               Washington Huskies  1.362992
#  276  S. Masereka  Maryland College Park Terrapins  0.409180
#  34     B. Liscum          Penn State Nittany Lion  0.256703
#  56     C. Dionne          Penn State Nittany Lion  0.253462
#  87    D. Herrera              Michigan Wolverines  0.000000
#  117     I. Abbey          Rutgers Scarlet Knights  0.000000
#  208    M. Rogers  Maryland College Park Terrapins  0.000000,
#  'RB':            player_name                             team   ranking
#  90   D. Onwona-Agyeman              Ohio State Buckeyes  1.762897
#  179        L. Shreiner            Northwestern Wildcats  1.409602
#  198        M. Marshall          Penn State Nittany Lion  1.254425
#  248         P. O'Toole              Michigan Wolverines  0.872156
#  255          R. Burlew                Wisconsin Badgers  0.480917
#  16            A. Nitzl  Maryland College Park Terrapins  0.000000
#  21          A. Samways              Ohio State Buckeyes  0.000000
#  37            B. Mayer            Northwestern Wildcats  0.000000
#  48          C. Buckley               Washington Huskies  0.000000
#  66            C. Leber               Washington Huskies  0.000000
#  91           D. Stopek          Rutgers Scarlet Knights  0.000000
#  127           J. Clark  Maryland College Park Terrapins  0.000000
#  251          Q. Elliot                 Indiana Hoosiers  0.000000
#  260          R. Ludwig          Michigan State Spartans  0.000000,
#  'RB5':      player_name                     team  ranking
#  38      B. Mayer    Northwestern Wildcats      0.0
#  92     D. Stopek  Rutgers Scarlet Knights      0.0
#  240  P. Greenlee              UCLA Bruins      0.0,
#  'RCB':       player_name                             team   ranking
#  309     W. Kulvik  Maryland College Park Terrapins  3.367414
#  225     N. Miller              Michigan Wolverines  0.914868
#  228     N. Prince            Northwestern Wildcats  0.532882
#  162   J. Zalinsky          Rutgers Scarlet Knights  0.335250
#  266    R. Quintos                Wisconsin Badgers  0.228250
#  44     B. Thiesen  Maryland College Park Terrapins  0.000000
#  97      E. Akulov               Washington Huskies  0.000000
#  123       J. Adam          Michigan State Spartans  0.000000
#  124      J. Bonas          Penn State Nittany Lion  0.000000
#  128      J. Clark  Maryland College Park Terrapins  0.000000
#  147     J. Miller                 Indiana Hoosiers  0.000000
#  205      M. Riley  Maryland College Park Terrapins  0.000000
#  218    N. Collins          Rutgers Scarlet Knights  0.000000
#  274  S. Magnusson              Ohio State Buckeyes  0.000000,
#  'RCB3':      player_name                     team   ranking
#  12    A. Legaspi              UCLA Bruins  1.213492
#  180  L. Shreiner    Northwestern Wildcats  0.000000
#  219   N. Collins  Rutgers Scarlet Knights  0.000000,
#  'RCMF':       player_name                     team   ranking
#  210   M. Sherlock       Washington Huskies  4.510626
#  245   P. McDonald         Indiana Hoosiers  4.103584
#  301      T. Villa      Ohio State Buckeyes  1.960992
#  215    N. Cabrera  Rutgers Scarlet Knights  0.803263
#  156   J. Suchecki    Northwestern Wildcats  0.496868
#  316    Z. Martens      Michigan Wolverines  0.364604
#  67        C. Lofy       Washington Huskies  0.198385
#  292      T. Gilej      Ohio State Buckeyes  0.000000
#  283       S. Sent       Washington Huskies  0.000000
#  253     Q. Rogers      Michigan Wolverines  0.000000
#  33       B. LeBel    Northwestern Wildcats  0.000000
#  224    N. McHenry      Ohio State Buckeyes  0.000000
#  45        C. Arce  Michigan State Spartans  0.000000
#  159    J. Wagoner         Indiana Hoosiers  0.000000
#  140       J. Kuhr        Wisconsin Badgers  0.000000
#  69      C. McCamy    Northwestern Wildcats  0.000000
#  212  M. Zachemski        Wisconsin Badgers  0.000000,
#  'RCMF3':     player_name         team   ranking
#  300  T. Ratoviz  UCLA Bruins  1.018529
#  98   E. Caceres  UCLA Bruins  0.000000,
#  'RDMF':          player_name                             team   ranking
#  264         R. Perez              Michigan Wolverines  3.769361
#  84        D. Carlson          Rutgers Scarlet Knights  1.276847
#  202        M. Parker              Michigan Wolverines  1.205879
#  185        M. Daouda          Penn State Nittany Lion  0.888773
#  317       Z. Martens              Michigan Wolverines  0.450938
#  103          E. Ruiz          Rutgers Scarlet Knights  0.291522
#  15       A. Ndrenika  Maryland College Park Terrapins  0.000000
#  17          A. Nitzl  Maryland College Park Terrapins  0.000000
#  77   C. Steinleitner  Maryland College Park Terrapins  0.000000
#  100         E. Jones                Wisconsin Badgers  0.000000,
#  'RW':        player_name                     team   ranking
#  280      S. Sarver         Indiana Hoosiers  1.834338
#  107   F. Di Ponzio  Rutgers Scarlet Knights  0.786342
#  47      C. Brunell       Washington Huskies  0.460527
#  78     C. Thaggard    Northwestern Wildcats  0.374471
#  193       M. Hewes  Penn State Nittany Lion  0.223811
#  136    J. Guggemos  Michigan State Spartans  0.000000
#  250         P. Son    Northwestern Wildcats  0.000000
#  241   P. Grinstead      Ohio State Buckeyes  0.000000
#  237  O. Stefansson        Wisconsin Badgers  0.000000
#  234      O. Foster                LMU Lions  0.000000
#  3         A. Bilow      Ohio State Buckeyes  0.000000
#  131        J. Dale       Washington Huskies  0.000000
#  24         A.Awujo    Northwestern Wildcats  0.000000
#  88      D. Herrera      Michigan Wolverines  0.000000
#  85        D. Davis      Michigan Wolverines  0.000000
#  29      B. Blevins      Michigan Wolverines  0.000000
#  120       I. Obeid    Northwestern Wildcats  0.000000,
#  'RWB':     player_name                 team   ranking
#  148   J. Nabaka  Michigan Wolverines  0.625012,
#  'RWF':      player_name                     team   ranking
#  288  T. Angelone  Rutgers Scarlet Knights  1.159277
#  65   C. Lawrence      Michigan Wolverines  0.212729
#  279    S. Rincón              UCLA Bruins  0.000000}
